# %%
def hra(b):
  return b*0.2
def da(b):
  return b*0.1
def net(b):
  return b+hra(b)+da(b)

n=input("Name: ")
b=float(input("Basic Salary: "))
print("HRA =",hra(b))
print("DA =",da(b))
print("Net Salary =",net(b))
# Out:
# Name: Sukhman
# Basic Salary: 30000
# HRA = 6000.0
# DA = 3000.0
# Net Salary = 39000.0

# %%
def total(m):
  return sum(m)
def per(t):
  return t/5
def grade(p):
    if p>=90:return "A"
    elif p>=75:return "B"
    elif p>=60:return "C"
    elif p>=40:return "D"
    return "F"

m=[int(input()) for i in range(5)]
t=total(m)
p=per(t)
print("Total =",t)
print("Percentage =",p)
print("Grade =",grade(p))
# Out:
# 65
# 54
# 77
# 70
# 80
# Total = 346
# Percentage = 69.2
# Grade = C

# %%
def total(m):
  return sum(m)
def per(t):
  return t/5
def grade(p):
    if p>=90:
      return"A"
    elif p>=75:
      return"B"
    elif p>=60:
      return"C"
    elif p>=40:
      return"D"
    return"F"

s=[]
n=int(input("Students: "))

for i in range(n):
    r=input("Roll: ")
    name=input("Name: ")
    m=[int(input()) for j in range(5)]
    p=per(total(m))
    s.append({"Roll number5":r,"Name":name,"Marks":m,"Per":p,"Grade":grade(p)})

for i in s:
    print(i)

print("Topper =",max(s,key=lambda x:x["Per"])["Name"])
# Out:
# Students: 2
# Roll: 3
# Name: rohan
# 34
# 54
# 65
# 66
# 66
# Roll: 1
# Name: aditi
# 33
# 56
# 88
# 66
# 55
# {'Roll number5': '3', 'Name': 'rohan', 'Marks': [34, 54, 65, 66, 66], 'Per': 57.0, 'Grade': 'D'}
# {'Roll number5': '1', 'Name': 'aditi', 'Marks': [33, 56, 88, 66, 55], 'Per': 59.6, 'Grade': 'D'}
# Topper = aditi

# %% [markdown]
# # File Handling

# %%
file = open("marks.txt","w+")
file.write("Rohan : 25 \n Rahul : 67 \n Ram : 44 \n Sita : 93 \n Geeta : 88")
file.close()

file = open("marks.txt","r")
cont = file.read()
print(cont)
file.close()
# Out:
# Rohan : 25
#  Rahul : 67
#  Ram : 44
#  Sita : 93
#  Geeta : 88

# %%
file = open("marks.txt", "r")

pass_count = 0
fail_count = 0

for i in file:
    name, marks = i.split(":")
    marks = int(marks.strip())
    name = name.strip()

    if marks > 45:
        print(name, "has passed the exam with", marks, "marks")
        pass_count += 1
    else:
        print(name, "has failed the exam with", marks, "marks")
        fail_count += 1

file.close()

print("\nPass Students:", pass_count)
print("Fail Students:", fail_count)
# Out:
# Rohan has failed the exam with 25 marks
# Rahul has passed the exam with 67 marks
# Ram has failed the exam with 44 marks
# Sita has passed the exam with 93 marks
# Geeta has passed the exam with 88 marks
#
# Pass Students: 3
# Fail Students: 2

# %%
file = open("salary.txt","w+")
file.write(" \n Rohan : 25000 \n Rahul : 67000 \n Ram : 44000 \n Sita : 93000 \n Geeta : 88000")
file.close()

file = open("salary.txt","r")
cont = file.read()
print(cont)
file.close()
# Out:
#
#  Rohan : 25000
#  Rahul : 67000
#  Ram : 44000
#  Sita : 93000
#  Geeta : 88000

# %%
file = open("salary.txt", "r")

employee_count=0

for i in file:
    name, salary = i.split()
    salary = int(salary.strip())
    name = name.strip()

    if salary > 50000:
        print(name, "has salary greater than 50k")
        employee_count += 1
    else:
        print(name, "has salary less than 50k")

file.close()

print("\nEmployee count:", employee_count)
# Out:
# Aman has salary greater than 50k
# Riya has salary less than 50k
# Simran has salary greater than 50k
# Karan has salary less than 50k
#
# Employee count: 2

# %%
file = open("attendance.txt","w+")
file.write(" \n Rohan : Absent \n Rahul : Present \n Ram : Present \n Sita : Present \n Geeta : Absent")
file.close()

file = open("attendance.txt","r")
cont = file.read()
print(cont)
file.close()
# Out:
#
#  Rohan : Absent
#  Rahul : Present
#  Ram : Present
#  Sita : Present
#  Geeta : Absent

# %%
file = open("attendance.txt", "r")

abs_count = 0
pre_count = 0

for i in file:
    name, attendance = i.split()
    attendance = attendance.strip()
    name = name.strip()

    if attendance == "Present":
        pre_count += 1
    else:
        print(name, "is absent")
        abs_count += 1

file.close()
total_students = pre_count + abs_count
print("\nTotal Students:", total_students)
# Out:
# Riya is absent
# Karan is absent
#
# Total Students: 4
